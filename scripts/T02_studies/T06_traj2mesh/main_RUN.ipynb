# %%
from model.RunYB_v2 import RunYB_v2
from model.default import *
from tools.basic.path_gen   import path_gen
import os

# %%
main_path = os.path.join("output/", path_gen())
p = default_v2()

# %%
p["lammps"]["hilo_central"] = 40
p["lammps"]["errate"] = 0
p["lammps"]["Npoints"] = 200
p["lammps"]["RUN_STEPS_DEFORM"] = 1000
p["lammps"]["RUN_STEPS_EQ"]     = 1
p["lammps"]["errate"]  = 0
p["lammps"]["nhilos"]  = 4 
p["lammps"]["r_hebra"] = 0.27/2 # mm
p["lammps"]["theta"] = 45 # deg
p["lammps"]["dist_factor"] = 1.1
p["lammps"]["r0_factor"] = 0.0005
p["lammps"]["yukawa"]["A"] = 5e3
p["lammps"]["recompute_dist"] = True
p["lammps"]["Remesh"] = False
p["lammps"]["V0_bond"] = 2e5

# %%
RunYB_v2(p,main_path)
# Out:
# Running lammps
# ...
# Authorization required, but no authorization protocol specified
# Authorization required, but no authorization protocol specified
# Running traj2mesh
# ...
# Running lsdyna
# ...
#   0%|          | 0/64 [00:00<?, ?it/s]
# Running gmsh
# ...
# 64it [00:38,  1.67it/s]
# Running inflation
# ...
# Nsets have been created
# Running Calculix at:  output/2023-12-20__09-49-10__73722/inflation
# Command:
#  wine /home/djoroya/projects/DIMAT/01_TECNORED_BRAID_v2/dependences/CalculiX-versions/ccx_static.exe init > out.txt
# Error reading cvf file
#
# pid:  338359
#
# SUMMARY OF C0NVERGENCE INFORMATION
#   STEP   INC  ATT   ITER     CONT.   RESID.        CORR.      RESID.      CORR.
#                               EL.    FORCE         DISP       FLUX        TEMP.
#                               (#)     (%)           (%)        (%)         (%)
#      1     1     1     1    16270  0.0000E+00  0.1000E+03  0.0000E+00  0.0000E+00
# ...
