# %%
from tools.basic.path_gen   import path_gen
from tools.step.pprint     import pprint

from model.default          import *

import os

from model.simulation.RunSimulation import RunSimulation

# %%
out_simula = os.path.join("output",path_gen())

# %%
inflation_path = "../T02_denier/final/2024-01-02__17-51-02__14471"
inflation_path ="../T02_denier/final/2024-01-03__08-21-01__39189" # 0 MPa
# inflation_path ="../T02_denier/final/2024-01-03__16-51-59__31192"
# inflation_path = "../T02_denier/final/2024-01-04__08-23-01__70168" 
# inflation_path = "../T02_denier/final/2024-01-05__12-03-56__59010" 
# short 
#inflation_path ="../T02_denier/final/2024-01-09__11-44-19__81959" # 0 MPa

#  medium long
inflation_path ="../T02_denier/final/2024-01-10__07-32-31__99756" # 200 MPa medium long

#  medium long
inflation_path ="../T02_denier/final/2024-01-11__12-04-21__64913" # 400 MPa medium long

#  medium long
inflation_path ="../T02_denier/final/2024-01-11__13-39-10__18176" # 800 MPa medium long


inflation_path ="../T02_denier/final/2024-01-12__08-52-25__53812" # 800 MPa  large

inflation_path ="../T02_denier/final/2024-01-12__12-09-07__63832" # 800 MPa  large high density

# inflation_path ="../T02_denier/final/2024-01-12__13-56-53__71979" # 800 MPa  small high density
inflation_path ="../T02_denier/final/2024-01-15__08-48-22__22729" # 800 MPa  small high density 0.9 gsmh
inflation_path ="../T02_denier/final/2024-01-15__09-58-37__13640" # 800 MPa  large 0.5 high density 0.9 gsmh

inflation_path ="../T02_denier/final/2024-01-15__13-06-47__67418" # 800 MPa  large 0.5 high density 0.9 gsmh # FACE TOP SETS ONLY CENTERS

inflation_path ="../T02_denier/final/2024-01-15__14-56-10__53812" # 800 MPa  large 0.5 high density 0.9 gsmh # FACE TOP SETS ONLY CENTERS

# %%
inflation_path = inflation_path + "/inflation"

inflation_path = r"C:\Users\djoroya\Documents\GitHub\YarnBraid\scripts\C02_YarnBraid\T04_studies\T04_validation\T02_denier\output\2024-02-14__16-54-31__85955\2024-02-14__18-26-47__64256\inflation"

# %%
params_simu = simulation_default()
params_simu["young"]         = 1500      # MPa
params_simu["poisson"]       = 0.37 # Pa
params_simu["epsilon"]       = 0.1
params_simu["inflation_path"] = inflation_path
params_simu["nsteps"]    = 6
params_simu["nruns"]    = 1
params_simu["nonlinear"]   = True
params_simu["Adjust"] = False
params_simu["cylindrical"] = True
params_simu["type_bc"]      = 1
params_simu["coment"] = "800 MPa medium long"
params_simu["surface_interaction"]["type"]  = "linear"
params_simu["surface_interaction"]["factor_E"] = 50

params_simu["mpi"] = True # number of cpus
pprint(params_simu)
# Out:
# elapsed             : 0 h  -  0 m  -  0 s
# error               : 1
# error_msg           : No execution
# verbose             : True
# young               : 1500
# poisson             : 0.37
# epsilon             : 0.1
# OMP_NUM_THREADS     : 4
# type_bc             : 1
# attemps             : 4
# Adjust              : False
# nfixed              : 3
# nsteps              : 6
# nonlinear           : True
# cylindrical         : True
# nruns               : 1
# surface_interaction :
# 	- type
# 	-factor_E
# 	-...
# max_mono            : None
# calculix_dynamic    : False
# mpi                 : True
# mpi_np              : 4
# inflation_path      : C:\Users\djoroya\Documents\GitHub\YarnBraid\scripts\C02_YarnBraid\T04_studies\T04_validation\T02_denier\output\2024-02-14__16-54-31__85955\2024-02-14__18-26-47__64256\inflation
# coment              : 800 MPa medium long

# %%
RunSimulation(params_simu,out_simula)
# Out:
# Running Calculix at:  output\2024-02-16__07-44-27__64335
# Output file:  c:\Users\djoroya\Documents\GitHub\YarnBraid\scripts\C02_YarnBraid\T04_studies\T04_validation\T03_young_mod\output\2024-02-16__07-44-27__64335\out.txt
# Command:
#  mpiexec -n 4 C:\Users\djoroya\Documents\GitHub\YarnBraid\src\dependences\calculix\PrePoMax_SEP_v2.0.0\Solver\ccx_dynamic.exe init_new
# Error reading cvf file
#
# pid:  16612
#
# SUMMARY OF C0NVERGENCE INFORMATION
#   STEP   INC  ATT   ITER     CONT.   RESID.        CORR.      RESID.      CORR.
#                               EL.    FORCE         DISP       FLUX        TEMP.
#                               (#)     (%)           (%)        (%)         (%)
#      1     1     1     1  1242877  0.8895E+06  0.1000E+03  0.0000E+00  0.0000E+00
#      1     1     1     2  1242287  0.3281E+06  0.1000E+03  0.0000E+00  0.0000E+00
#      1     1     1     3   888404  0.1089E+06  0.1988E+02  0.0000E+00  0.0000E+00
# ...
