# %%
from tools.basic.path_gen   import path_gen
from tools.step.pprint     import pprint

from model.default          import *

import os

from model.simulation.RunSimulation import RunSimulation

# %%
out_simula = os.path.join("output","only_sim",path_gen())

# %%
inflation_path = "output/2023-12-15__11-57-05__33057/2023-12-15__12-41-09__63135/inflation"
inflation_path = "/home/djoroya/projects/DIMAT/01_TECNORED_BRAID_v2/github/scripts/C02_YarnBraid/validation/output/only_infla/2023-12-15__17-06-41__23179/inflation"

inflation_path = "/home/djoroya/projects/DIMAT/01_TECNORED_BRAID_v2/github/scripts/C02_YarnBraid/validation/output/only_infla/2023-12-15__19-36-15__69547/inflation"

# %%
params_simu = simulation_default()
params_simu["young"]         = 2960      # MPa
params_simu["poisson"]       = 0.37 # Pa
params_simu["displacement"]  = 0.00001         # mm
params_simu["radius"]        = 10           # mm
params_simu["inflation_path"] = inflation_path
params_simu["type_bc"]      = 1

params_simu["ncpus"] = 16 # number of cpus
pprint(params_simu)
# Out:
# elapsed             : 0 h  -  0 m  -  0 s
# error               : 1
# error_msg           : No execution
# verbose             : True
# young               : 2960
# poisson             : 0.37
# displacement        : 1e-05
# ncpus               : 16
# type_bc             : 1
# attemps             : 4
# Adjust              : False
# nfixed              : 3
# radius              : 10
# inflation_path      : only_infla/2023-12-15__19-36-15__69547/inflation

# %%
RunSimulation(params_simu,out_simula)
# Out:
# Running Calculix at:  /home/djoroya/projects/DIMAT/01_TECNORED_BRAID_v2/github/scripts/C02_YarnBraid/validation/output/only_sim/2023-12-15__23-15-56__28387
# Command:
#  wine /home/djoroya/projects/DIMAT/01_TECNORED_BRAID_v2/dependences/CalculiX-versions/ccx_static.exe init_new > out.txt
# Error reading cvf file
#
# pid:  1416151
#
# SUMMARY OF C0NVERGENCE INFORMATION
#   STEP   INC  ATT   ITER     CONT.   RESID.        CORR.      RESID.      CORR.
#                               EL.    FORCE         DISP       FLUX        TEMP.
#                               (#)     (%)           (%)        (%)         (%)
#      1     1     1     1  2463865  0.2521E+06  0.1000E+03  0.0000E+00  0.0000E+00
#      1     1     1     2  1318286  0.8566E+05  0.2382E+02  0.0000E+00  0.0000E+00
#      1     1     1     3   729645  0.1806E+05  0.2141E+02  0.0000E+00  0.0000E+00
#      1     1     1     4   405202  0.7221E+04  0.2192E+02  0.0000E+00  0.0000E+00
# ...

# %%
print("Dol"           )
# Out:
# Dol
