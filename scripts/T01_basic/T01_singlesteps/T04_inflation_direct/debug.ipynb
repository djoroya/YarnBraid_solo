# %%
from tools.basic.loadsavejson import loadjson
import numpy as np
from matplotlib import pyplot as plt

# %%
df = loadjson("error.json")["df"]

# %%
df = [ df[df["type"]==i][["xu","yu","zu"]].values 
          for i in np.unique(df["type"]) ]

# %%
# %matplotlib ipympl

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

for i in range(55,64):
    ax.scatter(df[i][:,0], df[i][:,1], df[i][:,2], label=i+1)
plt.legend()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
from matplotlib import pyplot as plt

# %%
nodes_rot
# Out:
#       type       xu       yu        zu
# 0      1.0  2.66434 -1.30249   7.37333
# 1      1.0  2.62050 -1.50646   7.57946
# 2      1.0  2.59157 -1.64324   7.71232
# 3      1.0  2.57232 -1.70928   7.78104
# 4      1.0  2.53569 -1.76005   7.85641
# ...    ...      ...      ...       ...
# 3777  64.0 -2.50121 -1.34938  12.26230
# 3778  64.0 -2.43865 -1.38261  12.32830
# 3779  64.0 -2.36277 -1.39930  12.38560
# 3780  64.0 -2.29094 -1.43400  12.43840
# 3781  64.0 -2.22389 -1.46656  12.49570
#
# [3782 rows x 4 columns]

# %%
# 3d 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = nodes_rot[:,0]
y = nodes_rot[:,1]
z = nodes_rot[:,2]

ax.scatter(x, y, z)
#aspect ratio  to see real shape
ax.set_box_aspect([1,1,1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\djoroya\Documents\GitHub\YarnBraid-solo\.conda\Lib\site-packages\pandas\core\indexes\base.py:3790, in Index.get_loc(self, key)
#    3789 try:
# -> 3790     return self._engine.get_loc(casted_key)
#    3791 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:158, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# Cell In[26], line 5
#       2 fig = plt.figure()
#       3 ax = fig.add_subplot(111, projection='3d')
# ----> 5 x = nodes_rot[:,0]
#       6 y = nodes_rot[:,1]
#       7 z = nodes_rot[:,2]
#
# ...
