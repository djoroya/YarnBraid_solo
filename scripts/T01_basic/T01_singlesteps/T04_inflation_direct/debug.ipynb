# %%
from tools.basic.loadsavejson import loadjson

# %%
nodes_rot = loadjson("params.json")["data"]

# %%
from matplotlib import pyplot as plt

# %%
nodes_rot
# Out:
# array([[ 0.88903919, -3.03133514,  1.46401008],
#        [ 0.75951891, -2.67652916,  1.26990729],
#        [ 0.958051  , -3.61487029,  1.67132112],
#        ...,
#        [ 0.70206345, -2.87099952,  1.20496726],
#        [ 0.78727829, -4.48195154,  1.88000442],
#        [ 1.34183069, -6.04353396,  2.82254252]])

# %%
# %matplotlib ipympl

# %%
# 3d 
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

x = nodes_rot[:,0]
y = nodes_rot[:,1]
z = nodes_rot[:,2]

ax.scatter(x, y, z)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
