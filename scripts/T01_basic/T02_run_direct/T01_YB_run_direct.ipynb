# %%
from tools.step.pprint import pprint
import os

from models.direct.RunYB_direct   import RunYB
from models.direct.default import default

# %%
# Creamos la carpeta de salida
main_path = ["output"]

# %% [markdown]
# # Valores Constantes

# %%
#add ../../T00_params path
join = os.path.join

# %%
OMP_NUM_THREADS = 4
mpi_np = 6

r = default() # Valores por defecto
# Modificamos los valores que queremos
params_lmp = r["lammps_sim"]
params_lmp["Npoints"] = 250
params_lmp["RUN_STEPS_DEFORM"] = 4000
params_lmp["RUN_STEPS_EQ"]     = 1
params_lmp["errate"]  = 0
params_lmp["nhilos"]  = 4
params_lmp["r_hilo"] = 15
params_lmp["h"] =70
params_lmp["r_hebra"]        =  0.135
params_lmp["r_hebra_offset"] =  0.005
params_lmp["th_hebra"]       =  0.005


params_lmp["dist_factor"] = 0.2
params_lmp["r0_factor"] = 0.0005
params_lmp["yukawa"]["A"] = 3000
params_lmp["yukawa"]["kappa"] = 0.1
params_lmp["hilo_central"] = 10
params_lmp["Remesh"] = False
params_lmp["V0_bond"] = 1000 #40000 #38000
params_lmp["remove_final"] = False
params_lmp["OMP_NUM_THREADS"] = 4
params_lmp["mpi"] = True
# =============================================================================
params_gmsh = r["gmsh"]

# 1.2 - 1.9 0.75 length
params_gmsh["factor_mesh_min"] = 1.8# 1.8
params_gmsh["factor_mesh_max"] = 2.2 # 2.1
params_gmsh["factor_length"] = 0.75# 0.75 # 0.75 # 0.5
params_gmsh["factor_radius"] = 0.85
params_gmsh["Nalma"] = 0


params_gmsh["debug"] = True

# =============================================================================
params_infl = r["inflation"]
params_infl["auto_pressure"] = True
params_infl["OMP_NUM_THREADS"]     = 5
params_infl["mpi"]       = True
params_infl["mpi_np"]    = 5
params_infl["nsteps"]    = 2

# =============================================================================
params_simu = r["simulation"]
params_simu["young"]         = 2960      # MPa
params_simu["poisson"]       = 0.37 # Pa
params_simu["epsilon"]  = 0.5         # mm
params_simu["radius"]        = 10           # mm
params_simu["type_bc"]      = 2
params_simu["cylindrical"] = True # True
params_simu["mpi"] = True
params_simu["OMP_NUM_THREADS     "] = 4
params_simu["mpi_np"] = 4
params_simu["nsteps"] = 4
params_simu["ncpus"] = 4 # number of cpus
params_simu["only_braid"] = True

# =============================================================================
params_post = r["post"]

# %%
pprint(r)
# Out:
# settings_step       :
# 	- has_children
# 	-has_parent
# 	-verbose
# 	-...
# has_children        : True
# lammps_sim          :
# 	- settings_step
# 	-Npoints
# 	-hilo_central
# 	-theta
# 	-factor
# 	-Remesh
# 	-RUN_STEPS_EQ
# 	-RUN_STEPS_DEFORM
# 	-errate
# 	-nhilos
# 	-...
# gmsh                :
# 	- settings_step
# 	-factor_radius
# 	-factor_mesh_min
# 	-factor_mesh_max
# 	-debug
# 	-refine
# 	-lammps_path
# 	-factor_length
# 	-Nalma
# 	-...
# inflation           :
# 	- settings_step
# 	-pressure
# 	-OMP_NUM_THREADS
# 	-attemps
# 	-surface_behavior
# 	-radius_target
# 	-rho
# 	-calculix_dynamic
# 	-mpi
# 	-mpi_np
# 	-...
# simulation          :
# 	- settings_step
# 	-young
# 	-poisson
# 	-epsilon
# 	-OMP_NUM_THREADS
# 	-type_bc
# 	-attemps
# 	-Adjust
# 	-nfixed
# 	-nsteps
# 	-...
# post                :
# 	- settings_step
# 	-tensile_path
# 	-max_mono
# 	-...
# only_lammps         : False

# %%
r["lammps_sim"]["simulation_path"] = "2024-09-17__12-05-20__40822"
r["gmsh"]["simulation_path"]       = "2024-09-17__12-06-18__60256"
# r["inflation"]["simulation_path"]  = "2024-09-16__21-30-33__90471"
# r["simulation"]["simulation_path"] = "2024-09-16__15-51-45__23717"

# %%
r["simulation"]
# Out:
# {'settings_step': {'has_children': False,
#   'has_parent': False,
#   'verbose': True},
#  'young': 2960,
#  'poisson': 0.37,
#  'epsilon': 0.5,
#  'OMP_NUM_THREADS': 4,
#  'type_bc': 2,
#  'attemps': 4,
#  'Adjust': False,
#  'nfixed': 3,
#  'nsteps': 4,
#  'nonlinear': False,
#  'cylindrical': True,
#  'nruns': 1,
#  'surface_interaction': {'type': 'hard', 'factor_E': 50},
#  'max_mono': None,
#  'calculix_dynamic': False,
#  'mpi': True,
#  'mpi_np': 4,
#  'inflation_path': '',
#  'radius': 10,
#  'OMP_NUM_THREADS     ': 4,
#  'ncpus': 4,
#  'only_braid': True}

# %%
RunYB(r,main_path)
# Out:
# Running lammps
# ====================================
# Running gmsh
# ====================================
# Running inflation
# ====================================
# Running Calculix at:  c:\Users\djoroya\Documents\GitHub\YarnBraid-solo\simulations\2024-09-17__12-22-07__65662
# Output file:  c:\Users\djoroya\Documents\GitHub\YarnBraid-solo\simulations\2024-09-17__12-22-07__65662\out.txt
# Command:
#  mpiexec -n 5 c:\Users\djoroya\Documents\GitHub\YarnBraid_30_05_2024\YarnBraid\src\dependences\PrePoMax\Solver\ccx_dynamic.exe init
# Error reading cvf file
#
# pid:  2840
#
# SUMMARY OF C0NVERGENCE INFORMATION
#   STEP   INC  ATT   ITER     CONT.   RESID.        CORR.      RESID.      CORR.
#                               EL.    FORCE         DISP       FLUX        TEMP.
#                               (#)     (%)           (%)        (%)         (%)
#      1     1     1     1     4242  0.3292E+03  0.1000E+03  0.0000E+00  0.0000E+00
#      1     1     1     2     3856  0.6664E+01  0.2147E+02  0.0000E+00  0.0000E+00
#      1     1     1     3     3450  0.1818E+00  0.3365E+01  0.0000E+00  0.0000E+00
#      1     1     1     4     3414  0.8210E-01  0.2036E+01  0.0000E+00  0.0000E+00
#      1     1     1     5     3410  0.4943E-01  0.1570E+01  0.0000E+00  0.0000E+00
#      1     1     1     6     3413  0.3164E-01  0.1252E+01  0.0000E+00  0.0000E+00
#      2     1     1     1     3478  0.1007E+03  0.1000E+03  0.0000E+00  0.0000E+00
#      2     1     1     2    14459  0.4758E+02  0.2814E+02  0.0000E+00  0.0000E+00
#      2     1     1     3    11299  0.1082E+01  0.6322E+01  0.0000E+00  0.0000E+00
#      2     1     1     4    10765  0.5640E-01  0.2123E+01  0.0000E+00  0.0000E+00
#      2     1     1     5    10710  0.4688E-01  0.1637E+01  0.0000E+00  0.0000E+00
#      2     1     1     6    10702  0.4026E-01  0.1487E+01  0.0000E+00  0.0000E+00
#      2     1     1     7    10699  0.3603E-01  0.1380E+01  0.0000E+00  0.0000E+00
#      2     1     1     8    10693  0.3239E-01  0.1336E+01  0.0000E+00  0.0000E+00
#      2     1     1     9    10691  0.2921E-01  0.1285E+01  0.0000E+00  0.0000E+00
